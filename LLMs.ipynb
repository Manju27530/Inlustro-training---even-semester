# %% [markdown]
# <a href="https://colab.research.google.com/github/Manju27530/Inlustro-training---even-semester/blob/main/LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from diffusers import StableDiffusionPipeline
import torch
pipe=StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cpu")
prompt ="damon salvatore "
image=pipe(prompt).images[0]
image.show()
image.save("generated_image.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyC5SAr-5l3zDY9hPlp8DyMKJt_wRWjMPT4")
model=GenerativeModel("gemini-1.5-pro")
r=model.generate_content("how to make wine")
print(r.text)
# Out:
# Making wine is a rewarding process, but it requires patience and attention to detail. Here's a simplified guide to making wine at home:
#
# **1. Gather Your Equipment and Ingredients:**
#
# * **Primary Fermenter:** A food-grade plastic bucket or glass carboy (large bottle).
# * **Secondary Fermenter:** Another carboy or bucket (optional, but recommended for clearer wine).
# * **Airlock:** Allows CO2 to escape while preventing oxygen from entering.
# * **Siphon:** For transferring wine between containers without disturbing sediment.
# * **Bottles:** Wine bottles with corks or screw caps.
# * **Corker (if using corks):** A tool to insert corks into bottles.
# * **Sanitizer:**  Crucially important! Campden tablets (potassium metabisulfite) or a specialized wine sanitizer.
# * **Hydrometer:** Measures the sugar content of the must (grape juice) and helps estimate alcohol content.
# * **Wine Yeast:** Specific strains are available for different types of wine.
# ...

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyCyXVdUADae0f6T9HXEC6an9vRszA3k7ns")
model = GenerativeModel("gemini-1.5-pro")
print("Welcome to AI Chatbot! Type 'exit' to stop.")
while True:
 user_input = input("You: ")
 if user_input.lower() == "exit":
   break
 response = model.generate_content(user_input)
 print("AI:", response.text)
# Out:
# Welcome to AI Chatbot! Type 'exit' to stop.
# You: Hi
# AI: Hi there! How can I help you today?
#
# You: I love someone
# AI: That's wonderful! Love is a powerful and complex emotion.  Knowing you love someone can be a source of great joy and fulfillment.
#
# If you'd like to talk more about it, I'm here to listen.  Whether you're experiencing the initial excitement of new love, navigating the challenges of a long-term relationship, or just feeling the warmth of love for a friend or family member, feel free to share.
#
# Sometimes it helps to talk things through, even with a neutral listener like me.  I can offer a safe space for you to explore your feelings.
#
# You: Do you have heart
# AI: I do not have a heart in the biological sense. I am a large language model, an AI.  I don't have organs, emotions, or consciousness.
#
# ...

# %%
pip install deep_translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator
def translate_text(text, target_language):
    translator = GoogleTranslator(source='auto', target=target_language)
    return translator.translate(text)
text = "manju"
target_language = "ar"

translated_text = translate_text(text, target_language)
print(f"Original: {text}")
print(f"Translated ({target_language}): {translated_text}")
# Out:
# Original: manju
# Translated (ar): مانجو
